# %%
import pandas as pd

data= pd.read_csv("abalone.csv")

# %%
# To describe the data

print("Data describe")
print(data.describe())
# Out:
# Data describe
#        LongestShell     Diameter       Height  WholeWeight  ShuckedWeight  \
# count   4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean       0.523992     0.407881     0.139516     0.828742       0.359367
# std        0.120093     0.099240     0.041827     0.490389       0.221963
# min        0.075000     0.055000     0.000000     0.002000       0.001000
# 25%        0.450000     0.350000     0.115000     0.441500       0.186000
# 50%        0.545000     0.425000     0.140000     0.799500       0.336000
# 75%        0.615000     0.480000     0.165000     1.153000       0.502000
# max        0.815000     0.650000     1.130000     2.825500       1.488000
#
#        VisceraWeight  ShellWeight        Rings
# count    4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684
# std         0.109614     0.139203     3.224169
# min         0.000500     0.001500     1.000000
# 25%         0.093500     0.130000     8.000000
# ...

# %%
# Check for missing values
print("\nMissing values in the dataset:")
print(data.isnull().sum())
# Out:
# Missing values in the dataset:
# Type             0
# LongestShell     0
# Diameter         0
# Height           0
# WholeWeight      0
# ShuckedWeight    0
# VisceraWeight    0
# ShellWeight      0
# Rings            0
# dtype: int64

# %%
# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
# To create a bargraph


print(data.head())

average_whole_weight = data.groupby("Type")["WholeWeight"].mean()
average_shucked_weight = data.groupby("Type")["ShuckedWeight"].mean()
average_shell_weight = data.groupby("Type")["ShellWeight"].mean()

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,3))



average_whole_weight.plot(kind='bar', ax=axes[0], color='skyblue', title='Average Whole Weight by Type')
axes[0].set_xlabel('Type')
axes[0].set_ylabel('Average Whole Weight')


average_shucked_weight.plot(kind='bar', ax=axes[1], color='orange', title='Average Shucked Weight by Type')
axes[1].set_xlabel('Type')
axes[1].set_ylabel('Average Shucked Weight')


average_shell_weight.plot(kind='bar', ax=axes[2], color='green', title='Average Shell Weight by Type')
axes[2].set_xlabel('Type')
axes[2].set_ylabel('Average Shell Weight')


plt.tight_layout()


plt.show()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
# To display the first few rows of the dataset

print("First few rows of the dataset: ")
print(data.head())
# Out:
# First few rows of the dataset:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
#A pairplot

import seaborn as sns



data = pd.read_csv('abalone.csv')


print(data.head())


sns.pairplot(data, hue='Type')


plt.show()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
#Box Plot

print(data.head())

plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='WholeWeight', data=data)
plt.title('Box Plot of Whole Weight by Type')
plt.xlabel('Type')
plt.ylabel('Whole Weight')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='ShuckedWeight', data=data)
plt.title('Box Plot of Shucked Weight by Type')
plt.xlabel('Type')
plt.ylabel('Shucked Weight')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='ShellWeight', data=data)
plt.title('Box Plot of Shell Weight by Type')
plt.xlabel('Type')
plt.ylabel('Shell Weight')
plt.show()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
#Scatter Plot to compare whole weight vs shell weight


print(data.head())


plt.figure(figsize=(10, 6))
sns.scatterplot(x='WholeWeight', y='ShellWeight', hue='Type', data=data)
plt.title('Scatter Plot of Whole Weight vs. Shell Weight')
plt.xlabel('Whole Weight')
plt.ylabel('Shell Weight')
plt.legend(title='Type')
plt.show()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
#Histogram




plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='WholeWeight', hue='Type', multiple='stack', kde=True)
plt.title('Histogram of Whole Weight')
plt.xlabel('Whole Weight')
plt.ylabel('Count')
plt.show()


plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='ShuckedWeight', hue='Type', multiple='stack', kde=True)
plt.title('Histogram of Shucked Weight')
plt.xlabel('Shucked Weight')
plt.ylabel('Count')
plt.show()


plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='ShellWeight', hue='Type', multiple='stack', kde=True)
plt.title('Histogram of Shell Weight')
plt.xlabel('Shell Weight')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('abalone.csv')


plt.figure(figsize=(10, 6))
sns.violinplot(x='Type', y='WholeWeight', data=data)
plt.title('Violin Plot of Whole Weight by Type')
plt.xlabel('Type')
plt.ylabel('Whole Weight')
plt.show()


plt.figure(figsize=(10, 6))
sns.violinplot(x='Type', y='ShuckedWeight', data=data)
plt.title('Violin Plot of Shucked Weight by Type')
plt.xlabel('Type')
plt.ylabel('Shucked Weight')
plt.show()


plt.figure(figsize=(10, 6))
sns.violinplot(x='Type', y='ShellWeight', data=data)
plt.title('Violin Plot of Shell Weight by Type')
plt.xlabel('Type')
plt.ylabel('Shell Weight')
plt.show()

# %%
# Decision tree
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#Load data
data = pd.read_csv("abalone.csv")

#define the target variable and features
features = data.drop(columns=['Type'])
target = data['Type']

#Split data for training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

#Train decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

#Make predictions
y_pred = clf.predict(X_test)

#Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.48564593301435405
# Classification Report:
#               precision    recall  f1-score   support
#
#            F       0.39      0.39      0.39       377
#            I       0.67      0.64      0.65       419
#            M       0.41      0.42      0.42       458
#
#     accuracy                           0.49      1254
#    macro avg       0.49      0.48      0.49      1254
# weighted avg       0.49      0.49      0.49      1254
#
# Confusion Matrix:
# [[148  50 179]
#  [ 55 267  97]
#  [181  83 194]]

# %%
#Neural Network(NN)
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


# Load data
data = pd.read_csv("abalone.csv")

# Define the target variable and features
X = data.drop(columns=['Type'])
y = data['Type']


# Encode categorical target labels
le = LabelEncoder()
y = le.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Building the NN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
])

#Compiling the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Train of the model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_split=0.2)

#Set predictions
y_pred_prob = model.predict(X_test_scaled)
y_pred = y_pred_prob.argmax(axis=1)

#Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/50
# 74/74 [==============================] - 1s 5ms/step - loss: 0.9107 - accuracy: 0.5252 - val_loss: 0.8879 - val_accuracy: 0.5197
# Epoch 2/50
# 74/74 [==============================] - 0s 3ms/step - loss: 0.8649 - accuracy: 0.5483 - val_loss: 0.8752 - val_accuracy: 0.5333
# Epoch 3/50
# 74/74 [==============================] - 0s 2ms/step - loss: 0.8547 - accuracy: 0.5483 - val_loss: 0.8667 - val_accuracy: 0.5590
# Epoch 4/50
# 74/74 [==============================] - 0s 3ms/step - loss: 0.8510 - accuracy: 0.5453 - val_loss: 0.8591 - val_accuracy: 0.5316
# Epoch 5/50
# 74/74 [==============================] - 0s 3ms/step - loss: 0.8461 - accuracy: 0.5603 - val_loss: 0.8538 - val_accuracy: 0.5778
# Epoch 6/50
# 74/74 [==============================] - 0s 3ms/step - loss: 0.8424 - accuracy: 0.5637 - val_loss: 0.8511 - val_accuracy: 0.5538
# Epoch 7/50
# ...

# %%
#k-Nearest Neighbors (KNN) for classification using scikit-learn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#Load the data
data = pd.read_csv("abalone.csv")

#Define the target variable and features
X = data.drop(columns=['Type'])
y = data['Type']

#Encode categorical target labels
le = LabelEncoder()
y = le.fit_transform(y)

#Split the data for training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

#Initializing the KNN classifier
k = 5  # k express the number of neighbors
knn = KNeighborsClassifier(n_neighbors=k)

#Traing the classifier
knn.fit(X_train_scaled, y_train)

#To make predictions
y_pred = knn.predict(X_test_scaled)

#Now we are Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.532695374800638
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.47      0.44       377
#            1       0.68      0.74      0.71       419
#            2       0.49      0.39      0.44       458
#
#     accuracy                           0.53      1254
#    macro avg       0.53      0.54      0.53      1254
# weighted avg       0.53      0.53      0.53      1254
#
# Confusion Matrix:
# [[179  61 137]
#  [ 63 310  46]
#  [197  82 179]]
